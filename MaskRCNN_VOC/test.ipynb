# %%
import pickle
import import_ipynb
import MaskRCNN_VOC as mrv


import tqdm
import torch
import torchvision

import pickle


import numpy as np
import bbox_visualizer as bbv
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 range(0.1, 1, 0.1)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
with open("loss/no_expending(1th).p", "rb") as file:
    loss_list = pickle.load(file)

train_loss_list = [x.detach() for x in loss_list["train_loss_list"]]
val_loss_list = loss_list["val_loss_list"]
plt.plot(train_loss_list)
plt.plot(val_loss_list)

# %%
with open("loss/no_expending(2th).p", "rb") as file:
    loss_list = pickle.load(file)

train_loss_list = [x.detach() for x in loss_list["train_loss_list"]]
val_loss_list = loss_list["val_loss_list"]
plt.plot(train_loss_list)
plt.plot(val_loss_list)

# %%
with open("loss/no_expending(3th).p", "rb") as file:
    loss_list = pickle.load(file)

train_loss_list = [x.detach() for x in loss_list["train_loss_list"]]
val_loss_list = loss_list["val_loss_list"]
plt.plot(train_loss_list)
plt.plot(val_loss_list)

# %%
with open("loss/no_expending(4th).p", "rb") as file:
    loss_list = pickle.load(file)

train_loss_list = [x.detach() for x in loss_list["train_loss_list"]]
val_loss_list = loss_list["val_loss_list"]
plt.plot(train_loss_list)
plt.plot(val_loss_list)

# %%
with open("loss/no_expending(1th).p", "rb") as file:
    loss_list1 = pickle.load(file)

with open("loss/no_expending(2th).p", "rb") as file:
    loss_list2 = pickle.load(file)

with open("loss/no_expending(3th).p", "rb") as file:
    loss_list3 = pickle.load(file)

with open("loss/no_expending(4th).p", "rb") as file:
    loss_list4 = pickle.load(file)

i = 80
print(loss_list1["train_loss_list"][i])
print(loss_list2["train_loss_list"][i])
print(loss_list3["train_loss_list"][i])
print(loss_list4["train_loss_list"][i])

print(loss_list1["val_loss_list"][i])
print(loss_list2["val_loss_list"][i])
print(loss_list3["val_loss_list"][i])
print(loss_list4["val_loss_list"][i])
# Out:
# tensor(0.0361, requires_grad=True)
# tensor(0.0361, requires_grad=True)
# tensor(0.0362, requires_grad=True)
# tensor(0.0362, requires_grad=True)
# 0.036069505
# 0.03602712
# 0.036173284
# 0.03618957

# %%
loss_list1["train_loss_list"][]
# Out:
# [tensor(0.5536, requires_grad=True),
#  tensor(0.2116, requires_grad=True),
#  tensor(0.1307, requires_grad=True),
#  tensor(0.1019, requires_grad=True),
#  tensor(0.0877, requires_grad=True),
#  tensor(0.0793, requires_grad=True),
#  tensor(0.0724, requires_grad=True),
#  tensor(0.0676, requires_grad=True),
#  tensor(0.0638, requires_grad=True),
#  tensor(0.0606, requires_grad=True),
#  tensor(0.0580, requires_grad=True),
#  tensor(0.0556, requires_grad=True),
#  tensor(0.0536, requires_grad=True),
#  tensor(0.0522, requires_grad=True),
#  tensor(0.0506, requires_grad=True),
#  tensor(0.0496, requires_grad=True),
#  tensor(0.0485, requires_grad=True),
#  tensor(0.0475, requires_grad=True),
#  tensor(0.0465, requires_grad=True),
#  tensor(0.0457, requires_grad=True),
#  tensor(0.0449, requires_grad=True),
#  tensor(0.0443, requires_grad=True),
#  tensor(0.0436, requires_grad=True),
#  tensor(0.0431, requires_grad=True),
#  tensor(0.0426, requires_grad=True),
# ...

# %%
loss_list1["train_loss_list"][44]
loss_list1["val_loss_list"][2]
# Out:
# 0.11156733
