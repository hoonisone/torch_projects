# %%
from VOC2012_MaskRCNN_InstanceSegmentation import *

# %%
task = MaskRCNN("name", "./../result/1/boundary(size=2)/checkpoint(7)")
task.show_sample_result(idx = 0, type = "train", device = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [10], line 2
#       1 task = MaskRCNN("name", "./../result/1/boundary(size=2)/checkpoint(7)")
# ----> 2 task.show_sample_result(idx = 0, type = "train", device = 1)
#
# File ~/MH/torch_projects-main/MaskRCNN_VOC/script/VOC2012_MaskRCNN_InstanceSegmentation.py:659, in MaskRCNN.show_sample_result(self, idx, type, device)
#     655 sample_data = self.to_for_sample_data(self.get_dataset(type)[idx], device) # idx 번째 샘플 데이터(device 적용)
#     657 # result
# --> 659 sample_result = self.feed_for_sample_data(model, sample_data)
#     660 sample_result = self.trim_for_sample_result(sample_result)
#     662 if len(sample_result["labels"]) == 0:
#
# File ~/MH/torch_projects-main/MaskRCNN_VOC/script/VOC2012_MaskRCNN_InstanceSegmentation.py:543, in MaskRCNN.feed_for_sample_data(self, model, sample_data)
# ...
