# %%
import matplotlib.pyplot as plt
import numpy as np
import bbox_visualizer as bbv

# from ultralytics import YOLO
# from ultralytics.yolo.utils.ops import scale_image
import cv2
import numpy as np
from pathlib import Path

import mh_utils as MH
from VOC2012_MaskRCNN_InstanceSegmentation import *
from torch.nn.parallel import DistributedDataParallel as DDP
# Out:
# Customized: torchvision.models.detection.roi_heads.maskrcnn_loss

# %%
path = Path("./../result/0/benchmark/mask_images")

plt.figure(figsize=(7, 30))
for i in range(10):
    
    plt.subplot(10, 2, 2*i+1)
    image = plt.imread(path/f"masked_image({i}).png")
    plt.imshow(image)
    plt.gca().axes.xaxis.set_visible(False)
    plt.gca().axes.yaxis.set_visible(False)
    
    plt.subplot(10, 2, 2*i+2)
    image = plt.imread(path/f"masked_canvas({i}).png")
    plt.imshow(image)
    plt.gca().axes.xaxis.set_visible(False)
    plt.gca().axes.yaxis.set_visible(False)
    
plt.show()
