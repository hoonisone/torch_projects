# %%
import matplotlib.pyplot as plt
import numpy as np
import bbox_visualizer as bbv

# from ultralytics import YOLO
# from ultralytics.yolo.utils.ops import scale_image
import cv2
import numpy as np
from pathlib import Path

import mh_utils as MH
from VOC2012_MaskRCNN_InstanceSegmentation import *
from torch.nn.parallel import DistributedDataParallel as DDP
# Out:
# Customized: torchvision.models.detection.roi_heads.maskrcnn_loss

# %%
task = MaskRCNN("./../result/0/boundary(size=2)/checkpoint(10)")
_, _, v_dataset, _ = task.get_simple_dataset()

# plt.imshow(Converter.tensor_to_numpy_for_sample_image(v_dataset[0][0]))

# %%
sample_data = v_dataset[0]
sample_data = Converter.tensor_to_numpy_for_sample_data(sample_data)
masked_canvas = MH.aggregate(sample_data[0], sample_data[1]["masks"], alpha = 1)

# %%
plt.imshow(masked_canvas)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
